# %% [markdown]
# <a href="https://colab.research.google.com/github/Stinger101/CDAV/blob/main/day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lists

# %%
# creating lists manually by defining
students = ["john","mary","evans"]
print(students)
print(type(students))
# Out:
# ['john', 'mary', 'evans']
# <class 'list'>

# %%
# creating lists using typecasting
name="John"
name = list(name)
print(name)
# Out:
# ['J', 'o', 'h', 'n']

# %%
# creating list from string using split
school = "soma,riverdale,strathmore"
school.split(",")
# Out:
# ['soma', 'riverdale', 'strathmore']

# %% [markdown]
# # Escape characters and string formatting

# %%
paragraph ="""
this is a line
this is another line
this has a '
this has a \
"""
print(paragraph)
# Out:
# this is a line
# this is another line
# this has a '
# this has a

# %%
introduction = "I am John.\nMy age is 18."
print(introduction)
# Out:
# I am John.
# My age is 18.

# %%
introduction = "\tI am John.\n\tMy age is 18."
print(introduction)
# Out:
# 	I am John.
# 	My age is 18.

# %%
introduction = 'I\'m John.\nMy age is 18.'
print(introduction)
# Out:
# I'm John.
# My age is 18.

# %%
paragraph ="""
this is a line
this is another line
this has a '
this has a \
"""
print(paragraph.replace("\n","\t"))
# Out:
# 	this is a line	this is another line	this has a '	this has a

# %% [markdown]
# Mini school dataset(csv)

# %%
data = """name, gender, grade
john, m, 76
jane, f, 82
joseph, m, 84
susan, f, 72
"""

# %%
rows = data.split("\n")
print(rows[0].split(","))
# Out:
# ['name', ' gender', ' grade']

# %%
print(data.split("\n")[0].split(","))
# Out:
# ['name', ' gender', ' grade']

# %%
cols = data.split("\n")[0].split(",")

# %%
print(data.split("\n")[3].split(",")[2])
# Out:
#  84

# %%
cols
# Out:
# ['name', ' gender', ' grade']

# %%
cols[0]
# Out:
# 'name'

# %%
cols[-1]
# Out:
# ' grade'

# %%
cols[0:2]
# Out:
# ['name', ' gender']

# %%
cols[1:3]
# Out:
# [' gender', ' grade']

# %%
cols[-1:-3:-1]
# Out:
# [' grade', ' gender']

# %%
cols[::-1]
# Out:
# [' grade', ' gender', 'name']

# %%
cols[1] = "weight"
print(cols)
# Out:
# ['name', 'weight', ' grade']

# %%
cols.append("age")

# %%
print(cols)
# Out:
# ['name', 'weight', ' grade', 'age']

# %%
cols.pop()
# Out:
# 'age'

# %%
print(cols)
# Out:
# ['name', 'weight', ' grade']

# %%
cols.pop(1)
# Out:
# 'weight'

# %%
print(cols)
# Out:
# ['name', ' grade']

# %%
cols.insert(1,"weight")

# %%
print(cols)
# Out:
# ['name', 'weight', ' grade']

# %%
cols.remove("weight")

# %%
print(cols)
# Out:
# ['name', ' grade']

# %%
if "weight" in cols:
  cols.remove("weight")

# %%
cols.extend(["weight","age"])

# %%
print(cols)
# Out:
# ['name', ' grade', 'weight', 'age']

# %%
cols = cols+["address","email"]

# %%
print(cols)
# Out:
# ['name', ' grade', 'weight', 'age', 'address', 'email']

# %%
cols.index("weight")
# Out:
# 2

# %%
cols = cols+["address","email"]

# %%
print(cols)
# Out:
# ['name', ' grade', 'weight', 'age', 'address', 'email', 'address', 'email']

# %%
cols.count("address")
# Out:
# 2

# %%
cols.index("address")
# Out:
# 4

# %%
marks = [20,34,18,45,4,7]
marks.sort(reverse=True)

# %%
print(marks)
# Out:
# [45, 34, 20, 18, 7, 4]

# %%
vals = [10,20,30]
vals.append(40)
vals.insert(1,15)
avg = sum(vals)/len(vals)
print(f"the list contains {vals}. its average is {avg}")
# Out:
# the list contains [10, 15, 20, 30, 40]. its average is 23.0

# %% [markdown]
# create a program that keeps asking the user for numbers until they press =.
#
# the program should then output:
#
#
# *   sum
# *   lowest val
# *   highest val
# *   average val
#
# The program should not crash if the user enters a non-numerical val.

# %%
from ast import Break
nums = []
print("Welcome to stat calc")
while True:
  val = input("Enter an number(or = when done to get answers)")
  if val.isnumeric():
    nums.append(float(val))
  elif val == "=":
    print(f"The sum of {nums} is {sum(nums)}.")
    print(f"Their average is {sum(nums)/len(nums)}.")
    print(f"Their lowest val is {min(nums)} while the highest is {min(nums)}.")
    break
  else:
    print("that value was invalid. the values must be numbers")
# Out:
# Welcome to stat calc
# Enter an number(or = when done to get answers)10
# Enter an number(or = when done to get answers)20
# Enter an number(or = when done to get answers)30
# Enter an number(or = when done to get answers)=
# The sum of [10.0, 20.0, 30.0] is 60.0.
# Their average is 20.0.
# Their lowest val is 10.0 while the highest is 10.0.

# %% [markdown]
# # Tuples

# %%
rgb_color = (101,200,25)
print(type(rgb_color))
print(rgb_color)
# Out:
# <class 'tuple'>
# (101, 200, 25)

# %%
pi_val = (3.14)
pi_tup = (3.14,)
print(type(pi_val))
print(type(pi_tup))
# Out:
# <class 'float'>
# <class 'tuple'>

# %%
pi_val = 3.2

# %%
pi_tup[0] = 3.2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_469/4221710439.py in <cell line: 0>()
# ----> 1 pi_tup[0] = 3.2
#
# TypeError: 'tuple' object does not support item assignment

# %%
names_tup = ("John","Mary", "John", "Peter")
print(names_tup.index("Mary"))
print(names_tup.count("John"))
# Out:
# 1
# 2

# %%
a,b = (10,11)

# %%
print(b)
# Out:
# 11

# %%
for name in names_tup:
  print(name.upper())
# Out:
# JOHN
# MARY
# JOHN
# PETER

# %%
print([name.upper() for name in names_tup])
# Out:
# ['JOHN', 'MARY', 'JOHN', 'PETER']

# %% [markdown]
# # Sets

# %%
fruits = ["apple", "mango","apple","mango","banana"]
print(fruits)
# Out:
# ['apple', 'mango', 'apple', 'mango', 'banana']

# %%
fruits_set = {"apple", "mango","apple","mango","banana"}
print(fruits_set)
# Out:
# {'mango', 'apple', 'banana'}

# %%
fruits_set2 = set(fruits)
print(fruits_set2)
# Out:
# {'mango', 'apple', 'banana'}

# %%
fruits_set_upper = {fruit.upper() for fruit in fruits}
print(fruits_set_upper)
# Out:
# {'BANANA', 'APPLE', 'MANGO'}

# %%
fruits_set.add("plum")
print(fruits_set)
# Out:
# {'apple', 'kiwi', 'plum', 'mango', 'banana'}

# %%
fruits_set.discard("mango")
print(fruits_set)
# Out:
# {'apple', 'plum'}

# %% [markdown]
# #dictionaries

# %%
student_grades = {
    "math" : 80,
    "english": 95,
    "cre" : 92
}

print(type(student_grades))
# Out:
# <class 'dict'>

# %%
math_results = student_grades["math"]
print(math_results)
# Out:
# 80

# %%
student_grades["physics"] = 78
print(student_grades)
# Out:
# {'math': 80, 'english': 95, 'cre': 92, 'physics': 78}

# %%
student_grades["math"] = 82
print(student_grades)
# Out:
# {'math': 82, 'english': 95, 'cre': 92, 'physics': 78}

# %%
del student_grades["cre"]

# %%
print(student_grades)
# Out:
# {'english': 95, 'physics': 78}

# %%
student_grades.update({"math":70,"english":100})

# %%
print(student_grades)
# Out:
# {'english': 100, 'physics': 78, 'math': 70}

# %%
print(student_grades["math"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_469/202307389.py in <cell line: 0>()
# ----> 1 print(student_grades["math"])
#
# KeyError: 'math'

# %%
print(student_grades.get("math",0))
# Out:
# 0

# %%
student_grades.pop("math")
# Out:
# 70

# %%
student_grades
# Out:
# {'english': 100, 'physics': 78}

# %%
for key in student_grades.keys():
  print(key.upper())
# Out:
# ENGLISH
# PHYSICS

# %%
for val in student_grades.values():
  print(val)
# Out:
# 100
# 78

# %%
 for item in student_grades.items():
  print(item)
# Out:
# ('math', 80)
# ('english', 95)
# ('cre', 92)

# %%
for key, val in student_grades.items():
  print(key, "contains", val)
# Out:
# math contains 80
# english contains 95
# cre contains 92
